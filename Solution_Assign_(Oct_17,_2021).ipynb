# %% [markdown]
# Dataset Link: https://drive.google.com/file/d/12U3s3mgEvETZIH7V914b6Gh5jtfYLxiW/view?usp=sharing
#
# Submit your file here: https://docs.google.com/forms/d/e/1FAIpQLSez-Ffgu70i9jt4-g6vtM2Cdm_XK_xVONJikEbTZLKX8iPG_g/viewform?usp=sf_link

# %% [markdown]
# 1. Import the dataset and show the top 10 rows of dataset.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %% [markdown]
# 2. Show Shape and column names present in the dataset.

# %%
# columns
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#shape
df.shape
# Out:
# (891, 15)

# %% [markdown]
# 3. Show the information and description of dataset.

# %%
#Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#Description
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# 4. Show me the percentage wise missing values in the dataset.

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# 5. Find the no. of unique values present in the following features along with their value counts:
#
#   a) Survived
#
#   b) Pclass
#
#   c) Sex
#
#   d) Embarked

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Unique
print('Unique:', df['survived'].unique())
print('Value counts\n',df['survived'].value_counts())
# Out:
# Unique: [0 1]
# Value counts
#  0    549
# 1    342
# Name: survived, dtype: int64

# %% [markdown]
# 6. What is the range of age available of passengers.

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print('Minimum age present: ', min(df['age']))
print('Maximum age present: ', max(df['age']))
# Out:
# Minimum age present:  0.42
# Maximum age present:  80.0

# %% [markdown]
# 7. What is the number of passengers available
#
#   a). Less than age 13
#
#   b). Between age 13 and 18 (both inclusive)
#
#   c). Greater than age 18

# %%
#a)
df[df['age']<13].shape
# Out:
# (69, 15)

# %%
#b)
df[df['age']>12][df['age']<19].shape
# Out:
# <ipython-input-41-aeae8e919c0d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['age']>12][df['age']<19].shape
# (70, 15)

# %%
#c)
df[df['age']>18].shape
# Out:
# (575, 15)

# %% [markdown]
# 8. Plot 4 subplots having suitable width and height in which,
#
#   a). In the first subplot, show the visualization of count of passenger's gender.
#
#   b). In the second subplot, plot a piechart which shows the percentage wise distribution of gender.
#
#   c) In the third subplot, plot a scatterplot between Age and Fare with respect to gender.
#
#   d) In the fourth subplot, plot a Boxplot of Fare for different Passenger class(Pclass)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
fig, ax = plt.subplots(2,2, figsize = (15,10))

sns.countplot(x = 'sex', data = df, ax = ax[0,0])

male = np.round((df['sex'].value_counts()[0]/df.shape[0])*100, 2)
female = np.round((df['sex'].value_counts()[1]/df.shape[0])*100, 2)

ax[0,1].pie(df['sex'].value_counts(), labels = [male, female], colors = ['darkblue', 'pink'])
ax[0,1].legend(['Male', 'Female'])

sns.scatterplot(x = 'age', y = 'fare', hue = 'sex', data = df, ax = ax[1,0])
sns.boxplot(x = 'pclass', y = 'fare', data = df, ax = ax[1,1])

plt.show()

# %% [markdown]
# 9. Delete permanently the 'Name' and 'Ticket' column from the dataset.

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.drop(['parch', 'embark_town'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp     fare embarked  class    who  \
# 0         0       3    male  22.0      1   7.2500        S  Third    man
# 1         1       1  female  38.0      1  71.2833        C  First  woman
# 2         1       3  female  26.0      0   7.9250        S  Third  woman
# 3         1       1  female  35.0      1  53.1000        S  First  woman
# 4         0       3    male  35.0      0   8.0500        S  Third    man
#
#    adult_male deck alive  alone
# 0        True  NaN    no  False
# 1       False    C   yes  False
# 2       False  NaN   yes   True
# 3       False    C   yes  False
# 4        True  NaN    no   True

# %% [markdown]
# 10. Plot two subplots in which first subplot contains the visualization of count of male passengers according to Survived column and in the second subplot, do the same but for females.

# %%
male = df[df['sex']=='male']
female = df[df['sex']=='female']

# %%
male
# Out:
#      survived  pclass   sex   age  sibsp     fare embarked   class    who  \
# 0           0       3  male  22.0      1   7.2500        S   Third    man
# 4           0       3  male  35.0      0   8.0500        S   Third    man
# 5           0       3  male   NaN      0   8.4583        Q   Third    man
# 6           0       1  male  54.0      0  51.8625        S   First    man
# 7           0       3  male   2.0      3  21.0750        S   Third  child
# ..        ...     ...   ...   ...    ...      ...      ...     ...    ...
# 883         0       2  male  28.0      0  10.5000        S  Second    man
# 884         0       3  male  25.0      0   7.0500        S   Third    man
# 886         0       2  male  27.0      0  13.0000        S  Second    man
# 889         1       1  male  26.0      0  30.0000        C   First    man
# 890         0       3  male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck alive  alone
# 0          True  NaN    no  False
# 4          True  NaN    no   True
# 5          True  NaN    no   True
# 6          True    E    no   True
# 7         False  NaN    no  False
# ..          ...  ...   ...    ...
# 883        True  NaN    no   True
# 884        True  NaN    no   True
# 886        True  NaN    no   True
# 889        True    C   yes   True
# 890        True  NaN    no   True
#
# [577 rows x 13 columns]

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
sns.countplot(x = 'survived',data = male, ax = ax[0]).set_title('Male')
sns.countplot(x = 'survived', data = female, ax=ax[1]).set_title('Female')
plt.show()
